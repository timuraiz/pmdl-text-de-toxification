# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/filtered.tsv'
df = pd.read_csv(path, sep='\t', header=0)

# %%
df.head()
# Out:
#    Unnamed: 0                                          reference  \
# 0           0  If Alkar is flooding her with psychic waste, t...
# 1           1                          Now you're getting nasty.
# 2           2           Well, we could spare your life, for one.
# 3           3          Ah! Monkey, you've got to snap out of it.
# 4           4                   I've got orders to put her down.
#
#                                          translation  similarity  lenght_diff  \
# 0  if Alkar floods her with her mental waste, it ...    0.785171     0.010309
# 1                        you're becoming disgusting.    0.749687     0.071429
# 2                      well, we can spare your life.    0.919051     0.268293
# 3                       monkey, you have to wake up.    0.664333     0.309524
# 4                         I have orders to kill her.    0.726639     0.181818
#
#     ref_tox   trn_tox
# 0  0.014195  0.981983
# 1  0.065473  0.999039
# 2  0.213313  0.985068
# 3  0.053362  0.994215
# 4  0.009402  0.999348

# %% [markdown]
# I dont need similarity, lenght_diff

# %%
df = df.drop(columns=['similarity', 'lenght_diff', 'Unnamed: 0'])

# %%
df.head()
# Out:
#                                            reference  \
# 0  If Alkar is flooding her with psychic waste, t...
# 1                          Now you're getting nasty.
# 2           Well, we could spare your life, for one.
# 3          Ah! Monkey, you've got to snap out of it.
# 4                   I've got orders to put her down.
#
#                                          translation   ref_tox   trn_tox
# 0  if Alkar floods her with her mental waste, it ...  0.014195  0.981983
# 1                        you're becoming disgusting.  0.065473  0.999039
# 2                      well, we can spare your life.  0.213313  0.985068
# 3                       monkey, you have to wake up.  0.053362  0.994215
# 4                         I have orders to kill her.  0.009402  0.999348

# %%
mask = df['ref_tox'] < df['trn_tox']

# Swap the values where the condition is True
df.loc[mask, ['reference', 'translation']] = df.loc[mask, ['translation', 'reference']].values

# %%
df.head()
# Out:
#                                            reference  \
# 0  if Alkar floods her with her mental waste, it ...
# 1                        you're becoming disgusting.
# 2                      well, we can spare your life.
# 3                       monkey, you have to wake up.
# 4                         I have orders to kill her.
#
#                                          translation   ref_tox   trn_tox
# 0  If Alkar is flooding her with psychic waste, t...  0.014195  0.981983
# 1                          Now you're getting nasty.  0.065473  0.999039
# 2           Well, we could spare your life, for one.  0.213313  0.985068
# 3          Ah! Monkey, you've got to snap out of it.  0.053362  0.994215
# 4                   I've got orders to put her down.  0.009402  0.999348

# %%
df = df.drop(columns=['ref_tox', 'trn_tox'])

# %%
df.head()
# Out:
#                                            reference  \
# 0  if Alkar floods her with her mental waste, it ...
# 1                        you're becoming disgusting.
# 2                      well, we can spare your life.
# 3                       monkey, you have to wake up.
# 4                         I have orders to kill her.
#
#                                          translation
# 0  If Alkar is flooding her with psychic waste, t...
# 1                          Now you're getting nasty.
# 2           Well, we could spare your life, for one.
# 3          Ah! Monkey, you've got to snap out of it.
# 4                   I've got orders to put her down.

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Optional: Download NLTK data (if not already available)
import nltk
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    """
    Preprocesses the input text by performing several operations:
    - Lowercasing: Convert the text to lowercase to maintain consistency.
    - Tokenization: Split the text into individual words.
    - Removing stopwords: Optionally remove common words that may not be necessary for understanding the meaning.
    - Removing punctuation: Strip punctuation as it may not be needed.
    - Removing special characters: Remove any unwanted special characters.
    - Whitelist characters: Optionally, keep only alphanumeric characters.

    Args:
    - text (str): The text to be preprocessed.

    Returns:
    - str: The preprocessed text.
    """
    # Convert text to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove numbers and special characters, only keep letters
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords (optional)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Re-join tokens back to a single string
    text = ' '.join(tokens)

    return text

# Example usage:
reference = "Now you're getting nasty."
translation = "you're becoming disgusting."

# Preprocess the sentences
preprocessed_reference = preprocess_text(reference)
preprocessed_translation = preprocess_text(translation)

print("Preprocessed Reference:", preprocessed_reference)
print("Preprocessed Translation:", preprocessed_translation)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Preprocessed Reference: youre getting nasty
# Preprocessed Translation: youre becoming disgusting
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['reference'] = df['reference'].apply(preprocess_text)
df['translation'] = df['translation'].apply(preprocess_text)

# %%
df.head()
# Out:
#                                            reference  \
# 0  alkar floods mental waste would explain high l...
# 1                          youre becoming disgusting
# 2                                    well spare life
# 3                                        monkey wake
# 4                                        orders kill
#
#                                          translation
# 0  alkar flooding psychic waste explains high lev...
# 1                                youre getting nasty
# 2                          well could spare life one
# 3                           ah monkey youve got snap
# 4                                 ive got orders put

# %%
df.to_csv('/content/drive/MyDrive/filtered_and_prepocessed.csv', index=False)
